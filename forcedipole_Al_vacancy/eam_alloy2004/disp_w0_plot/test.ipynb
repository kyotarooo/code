# %%
import numpy as np #type: ignore
import matplotlib.pyplot as plt #type: ignore
import os
# Out:
# 'Python 3.11.9' でセルを実行するには、 ipykernel パッケージが必要です。
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Python 環境の作成</a> および必要なパッケージ。
#
# または、次のコマンドを使用して 'ipykernel' をインストールします: '/usr/local/bin/python3.11 -m pip install ipykernel -U --user --force-reinstall'
